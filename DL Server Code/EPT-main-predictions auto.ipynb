# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 2)) (0.19.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: lightning in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 5)) (0.17.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 6)) (1.21.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 9)) (0.21.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 10)) (2.0.3)
# Requirement already satisfied: pillow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 11)) (8.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 12)) (1.4.2)
# Requirement already satisfied: matplotlib==3.7.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 13)) (3.7.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 14)) (0.13.2)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 15)) (3.1.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 16)) (5.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 17)) (4.66.5)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 18)) (3.1.5)
# Requirement already satisfied: timm in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 19)) (1.0.8)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 20)) (1.4.13)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (2.20.5)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==3.0.0; platform_system == "Linux" and platform_machine == "x86_64" and python_version < "3.13" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (3.15.4)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.8/dist-packages (from lightning->-r requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.8/dist-packages (from lightning->-r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from lightning->-r requirements.txt (line 4)) (0.11.6)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.8/dist-packages (from lightning->-r requirements.txt (line 4)) (21.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from lightning->-r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/lib/python3/dist-packages (from wandb->-r requirements.txt (line 5)) (2.22.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (58.5.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (2.12.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (4.2.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.12.0; python_version < "3.9" and sys_platform == "linux" in /usr/local/lib/python3.8/dist-packages (from wandb->-r requirements.txt (line 5)) (3.19.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->-r requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->-r requirements.txt (line 9)) (1.4.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.8/dist-packages (from scikit-image->-r requirements.txt (line 9)) (2023.7.10)
# Requirement already satisfied: lazy_loader>=0.2 in /usr/local/lib/python3.8/dist-packages (from scikit-image->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: imageio>=2.27 in /usr/local/lib/python3.8/dist-packages (from scikit-image->-r requirements.txt (line 9)) (2.34.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.8/dist-packages (from pandas->-r requirements.txt (line 10)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.8/dist-packages (from pandas->-r requirements.txt (line 10)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas->-r requirements.txt (line 10)) (2024.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.7.3->-r requirements.txt (line 13)) (2.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.7.3->-r requirements.txt (line 13)) (5.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.7.3->-r requirements.txt (line 13)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.7.3->-r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.7.3->-r requirements.txt (line 13)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.7.3->-r requirements.txt (line 13)) (1.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.8/dist-packages (from bokeh->-r requirements.txt (line 15)) (2024.6.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.8/dist-packages (from bokeh->-r requirements.txt (line 15)) (6.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly->-r requirements.txt (line 16)) (9.0.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl->-r requirements.txt (line 18)) (1.1.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.8/dist-packages (from timm->-r requirements.txt (line 19)) (0.24.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.8/dist-packages (from timm->-r requirements.txt (line 19)) (0.4.4)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.8/dist-packages (from albumentations->-r requirements.txt (line 20)) (4.10.0.84)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.8/dist-packages (from albumentations->-r requirements.txt (line 20)) (2.8.2)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.8/dist-packages (from albumentations->-r requirements.txt (line 20)) (0.2.0)
# Requirement already satisfied: albucore>=0.0.13 in /usr/local/lib/python3.8/dist-packages (from albumentations->-r requirements.txt (line 20)) (0.0.13)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.8/dist-packages (from nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64"->torch->-r requirements.txt (line 1)) (12.6.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from sympy->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: urllib3>=1.26.11 in /usr/local/lib/python3.8/dist-packages (from sentry-sdk>=1.0.0->wandb->-r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from sentry-sdk>=1.0.0->wandb->-r requirements.txt (line 5)) (2019.11.28)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib==3.7.3->-r requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.8/dist-packages (from pydantic>=2.7.0->albumentations->-r requirements.txt (line 20)) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from pydantic>=2.7.0->albumentations->-r requirements.txt (line 20)) (0.7.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.8/dist-packages (from albucore>=0.0.13->albumentations->-r requirements.txt (line 20)) (2.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 5)) (5.0.1)
# WARNING: You are using pip version 20.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install -e .
# Out:
# Obtaining file:///tf/notebooks/EPT/1_taxonomist
# Installing collected packages: taxonomist
#   Attempting uninstall: taxonomist
#     Found existing installation: taxonomist 0.0.3
#     Can't uninstall 'taxonomist'. No files were found to uninstall.
#   Running setup.py develop for taxonomist
# Successfully installed taxonomist
# WARNING: You are using pip version 20.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
import glob

def list_files_with_prefix(directory, prefix):
    # Define the pattern for the files to search
    pattern = os.path.join(directory, f"{prefix}*")
    
    # Use glob to find files matching the pattern
    files = glob.glob(pattern)
    
    return files

def list_ckpts(directory):
    # Define the pattern for the files to search    
    pattern = os.path.join(directory, '*.ckpt')
    
    # Use glob to find files matching the pattern, with recursive search
    ckpt_files = glob.glob(pattern)
    
    filtered_files = [f for f in ckpt_files if not f.endswith('_last.ckpt')]     # Filter out files ending with '_last.ckpt'
    
    # Return the first file from the filtered list or None if the list is empty
    return filtered_files

def extend_fold_dict(directory):
    subfolders = [f.path for f in os.scandir(directory) if f.is_dir()]
    for subfolder in subfolders:
        fold_dict[int(subfolder[-1])].extend(list_ckpts(subfolder))

# %%
directory = "outputs/biodiscover/"
prefix = 'f08_ept-14'

    
fold_dict={}
for number in range(0,5):
    fold_dict[number] = []

# List the files
setting_folders = list_files_with_prefix(directory, prefix)

for sf in setting_folders:
    extend_fold_dict(sf)

# %%
for fold, ls in fold_dict.items():
    for file in ls:
        # Automatic predictiongs using the first (best) model checkpoint in the directory.
        # !python scripts/03_predict.py \
            --data_folder "../0_images/" \
            --dataset_config "conf/user_datasets.py" \
            --dataset_name "biodiscover" \
            --csv_path "data/processed/ept/01_EPT_processed_5splits_Final_species_label.csv" \
            --label "Final_species_label" \
            --fold {fold} \
            --class_map "data/processed/class_map_location.txt" \
            --imsize 224 \
            --batch_size 1024 \
            --aug 'none' \
            --out_folder 'outputs' \
            --tta 'False' \
            --out_prefix '' \
            --ckpt_path {file}
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:50<00:00,  0.55it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8279761075973511
#          test/f1            0.8136148452758789
#      test/loss_epoch        0.5225781798362732
# ────────────────────────────────────────────────────────────────────────────────
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.73it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8688793778419495
#          test/f1            0.8587017059326172
#      test/loss_epoch        0.7608242034912109
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0_f0_240814-1841-72d0_epoch85_val-loss0.82_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.73it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8066869378089905
#          test/f1            0.8125283122062683
#      test/loss_epoch        0.7179765701293945
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0_f0_240807-1248-5bfd_epoch00_val-loss0.99_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:39<00:00,  0.72it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc             0.841377854347229
#          test/f1            0.8302158713340759
#      test/loss_epoch        0.8576589226722717
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0_f0_240806-1313-b1a0_epoch15_val-loss0.95_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:  86%|██████████████████   | 24/28 [00:30<00:05,  0.79it/s]INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:40<00:00,  0.69it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8394583463668823
#          test/f1             0.827560544013977
#      test/loss_epoch        0.5346453189849854
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img_25_lr1e-05_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img_25_lr1e-05_test_run_efficientnet_b0_f0_240808-2109-edab_epoch58_val-loss0.55_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.72it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8401214480400085
#          test/f1            0.8291597962379456
#      test/loss_epoch          0.5261190533638
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img_50_lr1e-05_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img_50_lr1e-05_test_run_efficientnet_b0_f0_240809-0334-f2d3_epoch27_val-loss0.57_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.73it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8620737791061401
#          test/f1            0.8514936566352844
#      test/loss_epoch        0.5762766003608704
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_imgbel_lr0.0005_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_imgbel_lr0.0005_test_run_efficientnet_b0_f0_240816-1949-ef91_epoch00_val-loss0.62_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.72it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8404704332351685
#          test/f1            0.8302249312400818
#      test/loss_epoch        0.5337678790092468
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img100_lr1e-05_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img100_lr1e-05_test_run_efficientnet_b0_f0_240809-2238-15dc_epoch17_val-loss0.59_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:36<00:00,  0.78it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8076990246772766
#          test/f1            0.8009032607078552
#      test/loss_epoch        0.6651075482368469
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img_75_lr0.001_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img_75_lr0.001_test_run_efficientnet_b0_f0_240809-0753-e0df_epoch00_val-loss0.75_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:36<00:00,  0.77it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8527204990386963
#          test/f1            0.8419082760810852
#      test/loss_epoch        0.6556410789489746
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img100_lr0.001_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img100_lr0.001_test_run_efficientnet_b0_f0_240809-1731-6251_epoch00_val-loss0.77_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:35<00:00,  0.78it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8395979404449463
#          test/f1            0.8308380246162415
#      test/loss_epoch         0.763929545879364
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img_25_lr0.001_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img_25_lr0.001_test_run_efficientnet_b0_f0_240808-1920-e543_epoch03_val-loss0.68_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:35<00:00,  0.79it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc             0.828988254070282
#          test/f1            0.8159688711166382
#      test/loss_epoch        0.5509849786758423
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_imgbel_lr0.0001_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_imgbel_lr0.0001_test_run_efficientnet_b0_f0_240817-2059-64ae_epoch00_val-loss0.51_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:36<00:00,  0.78it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8379227519035339
#          test/f1            0.8260164260864258
#      test/loss_epoch        0.5043786764144897
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_imgbel_lr1e-05_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_imgbel_lr1e-05_test_run_efficientnet_b0_f0_240808-0200-1b07_epoch04_val-loss0.50_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:35<00:00,  0.79it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8401912450790405
#          test/f1            0.8352996706962585
#      test/loss_epoch        0.7544083595275879
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img300_lr0.001_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img300_lr0.001_test_run_efficientnet_b0_f0_240811-1342-1baf_epoch02_val-loss0.77_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:36<00:00,  0.77it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8814085721969604
#          test/f1             0.870343029499054
#      test/loss_epoch        0.5177799463272095
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img500_lr0.001_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img500_lr0.001_test_run_efficientnet_b0_f0_240813-1638-d7a6_epoch00_val-loss0.75_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:35<00:00,  0.78it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8423202037811279
#          test/f1            0.8313464522361755
#      test/loss_epoch        0.49457234144210815
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img400_lr1e-05_test_run_efficientnet_b0/f0/predictions/biodiscover_none/_f08_ept-14_img400_lr1e-05_test_run_efficientnet_b0_f0_240813-0418-3c8c_epoch05_val-loss0.53_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# ...
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.74it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8334441781044006
#          test/f1            0.8190091252326965
#      test/loss_epoch        0.5188307166099548
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img_10_lr1e-05_test_run_efficientnet_b0/f2/predictions/biodiscover_none/_f08_ept-14_img_10_lr1e-05_test_run_efficientnet_b0_f2_240808-1753-494d_epoch84_val-loss0.53_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.73it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8410769701004028
#          test/f1            0.8307427763938904
#      test/loss_epoch        0.49746647477149963
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img150_lr1e-05_test_run_efficientnet_b0/f2/predictions/biodiscover_none/_f08_ept-14_img150_lr1e-05_test_run_efficientnet_b0_f2_240810-1501-a1db_epoch07_val-loss0.53_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.73it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8674066066741943
#          test/f1            0.8572003245353699
#      test/loss_epoch        0.8498041033744812
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img200_lr0.001_test_run_efficientnet_b0/f2/predictions/biodiscover_none/_f08_ept-14_img200_lr0.001_test_run_efficientnet_b0_f2_240810-2302-9b89_epoch07_val-loss0.69_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:37<00:00,  0.74it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8523511290550232
#          test/f1            0.8470891118049622
#      test/loss_epoch        0.6323358416557312
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img150_lr0.001_test_run_efficientnet_b0/f2/predictions/biodiscover_none/_f08_ept-14_img150_lr0.001_test_run_efficientnet_b0_f2_240810-0742-9b27_epoch00_val-loss0.69_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████| 28/28 [00:38<00:00,  0.73it/s]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/acc            0.8422324061393738
#          test/f1            0.8322462439537048
#      test/loss_epoch        0.49671879410743713
# ────────────────────────────────────────────────────────────────────────────────
# outputs/biodiscover/f08_ept-14_img_75_lr1e-05_test_run_efficientnet_b0/f2/predictions/biodiscover_none/_f08_ept-14_img_75_lr1e-05_test_run_efficientnet_b0_f2_240809-1424-83d0_epoch15_val-loss0.51_none.csv
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# /tf/notebooks/EPT/1_taxonomist/src/taxonomist/taxonomist_model.py:474: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/efficientnet_b0.ra_in1k)
# INFO:timm.models._hub:[timm/efficientnet_b0.ra_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:  10%|██▎                   | 3/29 [00:03<00:26,  0.99it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import os
import glob

def list_files_with_prefix(directory, prefix):
    pattern = os.path.join(directory, f"{prefix}*")
    files = glob.glob(pattern)
    
    return files

def list_csvs(directory): 
    pattern = os.path.join(directory, 'predictions', 'biodiscover_none', '*.csv')
    csv_files = glob.glob(pattern)
    return csv_files

def extend_run_dict_csv(directory):
    subfolders = [f.path for f in os.scandir(directory) if f.is_dir()]
    for subfolder in subfolders:
        run_dict_csv[subfolder[:-3]].extend(list_csvs(subfolder))

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
def confusion_matrixX(y_true, 
                      y_pred, 
                      classes, 
                      figsize=(15,15), 
                      fonts=(18,10,18), 
                      rotate=False,
                      grid=False,
                      normalize='true'):

    # Check the inputs
    s_true = set(np.unique(y_true))
    s_pred = set(np.unique(y_pred))

    if classes == 'union':
        classes = sorted(list(s_true | s_pred))

    if len((s_true | s_pred) - set(classes)) > 0:
        warnings.warn(f"The inputs contain classes not present in the class list: {(s_true | s_pred) - set(classes)}")

    cm = confusion_matrix(y_true, 
                          y_pred, 
                          labels=classes,
                          normalize=normalize)
    
    if normalize:
        cm = cm*100
    fig, ax = plt.subplots(figsize=figsize)

    mask = np.zeros_like(cm)
    mask[cm==0] = 1
    sns.heatmap(cm, 
                annot=True, 
                annot_kws={"size": fonts[0]},
                fmt='.0f', 
                cmap="YlGnBu",
                xticklabels=classes, 
                yticklabels=classes,
                mask=mask,
                square=True, 
                cbar=False,
                ax=ax)
    
    if grid:
        ax.set_axisbelow(True)
        ax.yaxis.grid(color='gray', linestyle='dashed')
        ax.xaxis.grid(color='gray', linestyle='dashed')

    ax.set_ylabel('True label', size=fonts[2])
    ax.set_xlabel('Predicted label', size=fonts[2])
    ax.yaxis.set_ticks_position('none') 
    ax.xaxis.set_ticks_position('none') 
    
    if rotate:
        if isinstance(rotate, list):
            rot_x = rotate[0]
            rot_y = rotate[1]
        else:
            rot_x = rot_y = rotate
        plt.setp(ax.get_yticklabels(), rotation=rot_x, ha="right", rotation_mode="anchor", size=fonts[1])
        plt.setp(ax.get_xticklabels(), rotation=rot_y, ha="right", rotation_mode="anchor", size=fonts[1])
    else:
        plt.setp(ax.get_yticklabels(), size=fonts[1])
        plt.setp(ax.get_xticklabels(), size=fonts[1])
    fig.suptitle(run.split('/')[-1], fontsize=16)

from sklearn.metrics import classification_report
def classification_reportX(*args, 
                           figsize=None, 
                           fonts=(12,10,10),
                           rotate=True, 
                           bbox_anchor=(1.15,0.8), 
                           **kwargs):
    """Extends classification report by adding an useful plot for the performance across classes"""
    print('generating classification report files for '+run.split('/')[-1])
    r = classification_report(*args, **kwargs, output_dict=True)
    rdf0 = pd.DataFrame(r)
    rdf = rdf0.T.iloc[:-3,:].sort_values('support',ascending=False)
    fig, ax1 = plt.subplots(figsize=figsize)
    ax2 = ax1.twinx()

    xbar = range(len(rdf))
    ax1.bar(xbar,rdf['support'], alpha=0.2)
    ax2.plot(rdf['f1-score'], 'ro', label='f1-score')
    ax2.plot(rdf['precision'], 'g*', label='precision', alpha=0.5)
    ax2.plot(rdf['recall'], 'b*', label='recall', alpha=0.5)

    ax2.vlines(xbar, rdf['f1-score'], rdf['precision'], 'g')
    ax2.vlines(xbar, rdf['f1-score'], rdf['recall'], 'b')

    ax2.hlines(rdf0['weighted avg']['f1-score'], 0,len(rdf), color='r', linestyle='--', label='weighted f1-score')
    ax2.hlines(rdf0['macro avg']['f1-score'], 0,len(rdf), color='r', linestyle='-.', label='macro f1-score')
    ax2.hlines(rdf0['accuracy']['recall'], 0,len(rdf), color='b', linestyle='--', label='accuracy')
    
    if rotate:
        plt.setp(ax1.get_xticklabels(), 
                 rotation=45, 
                 ha="right", 
                 rotation_mode="anchor",
                 size=fonts[1])

    fig.legend(bbox_to_anchor=bbox_anchor,
               prop={"size": fonts[2]})
    
    ax2.set_ylabel("Score", size=fonts[0])
    ax1.set_ylabel("Support", size=fonts[0])
    plt.setp(ax1.get_yticklabels(),
             size=fonts[0])
    plt.setp(ax2.get_yticklabels(),
             size=fonts[0])
    plt.suptitle(run.split('/')[-1], fontsize=16)
    
    return classification_report(*args, **kwargs)

# %%
directory = "outputs/biodiscover/"
prefix = "f08_ept-14"

    
run_dict_csv={}
for run in list_files_with_prefix(directory, prefix):
    run_dict_csv[run] = []
# List the files
setting_folders = list_files_with_prefix(directory, prefix)

for sf in setting_folders:
    extend_run_dict_csv(sf)

# %%
import pandas as pd
from pathlib import Path

for run, ls in run_dict_csv.items():
    print('joining '+ run)

    df_f0 = pd.read_csv(ls[0])
    df_f1 = pd.read_csv(ls[1])
    df_f2 = pd.read_csv(ls[2])
    df_f3 = pd.read_csv(ls[3])
    df_f4 = pd.read_csv(ls[4])
    ref = pd.read_csv('data/processed/ept/01_EPT_processed_5splits_Final_species_label.csv')

    df = pd.concat([df_f0, df_f1, df_f2, df_f3, df_f4])

    # Get just the filename from the full path
    df["fname"] = df["fname"].apply(lambda x: Path(x).name)
    preds = df[["fname", "y_pred"]].set_index("fname")

    # Join the dataframes. 'inner' to keep only the rows that are in both dataframes
    results_df = ref.join(preds, how="inner", on="Image File Name")  

    # Choose wanted columns
    results_df = results_df[["Final_species_label", "y_pred", "individual"]]

    # Grouped by individual
    results_df_grouped = results_df.groupby(["individual"]).agg(lambda x: pd.Series.mode(x)[0])
    results_df_grouped.to_csv(os.path.join(run, run.split('/')[-1]+'_grouped_predictions.csv')) #_was added too late
    
    with open(os.path.join(run, run.split('/')[-1]+'_classification_report.txt'), 'w') as f:
        print(classification_reportX(results_df_grouped["Final_species_label"],
                                     results_df_grouped["y_pred"],
                                     zero_division=0,
                                     bbox_anchor=(1.3,0.8)), file=f)
    plt.tight_layout()
    plt.savefig(os.path.join(run, run.split('/')[-1]+'_report.png'))
    plt.close()
    
    confusion_matrixX(results_df_grouped["Final_species_label"], results_df_grouped["y_pred"], classes='union')
    plt.tight_layout()
    plt.savefig(os.path.join(run, run.split('/')[-1]+'conf_matrix.png'))
    plt.close()
# Out:
# joining outputs/biodiscover/f08_ept-14_img400_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img400_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_imgbel_lr0.005_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_10_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_10_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img200_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img200_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_25_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_25_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_50_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_50_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_imgbel_lr0.0005_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_imgbel_lr0.0005_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img100_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img100_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_75_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_75_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img100_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img100_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_25_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_25_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_imgbel_lr0.0001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_imgbel_lr0.0001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_imgbel_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_imgbel_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img300_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img300_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img500_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img500_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img400_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img400_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img500_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img500_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_50_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_50_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_imgbel_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_imgbel_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img300_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img300_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_10_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_10_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img150_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img150_lr1e-05_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img200_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img200_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img150_lr0.001_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img150_lr0.001_test_run_efficientnet_b0
# joining outputs/biodiscover/f08_ept-14_img_75_lr1e-05_test_run_efficientnet_b0
# generating classification report files for f08_ept-14_img_75_lr1e-05_test_run_efficientnet_b0

# %%
results_df_grouped
# Out:
#                    Final_species_label                      y_pred
# individual
# 10_A10            Athripsodes cinereus        Athripsodes cinereus
# 10_A11                    Goera pilosa                Goera pilosa
# 10_A12            Chaetopteryx villosa         Limnephilus lunatus
# 10_A2                    Baetis vernus              Baetis rhodani
# 10_A3                   Baetis rhodani              Baetis rhodani
# ...                                ...                         ...
# 9_H5                      Goera pilosa                Goera pilosa
# 9_H6              Athripsodes cinereus        Athripsodes cinereus
# 9_H7               Limnephilus lunatus         Limnephilus lunatus
# 9_H8               Limnephilus lunatus         Limnephilus lunatus
# 9_H9        Potamophylax rotundipennis  Potamophylax rotundipennis
#
# [690 rows x 2 columns]
